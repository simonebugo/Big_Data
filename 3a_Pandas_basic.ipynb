# %% [markdown]
# <a href="https://colab.research.google.com/github/simonebugo/Big_Data/blob/main/3a_Pandas_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Getting started with Pandas
#
# 1. Official Pandas tutorial (https://pandas.pydata.org/)
# 2. Pandas is one of the most used library for data science

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #Pandas has two main data structures:
#
# 1. Series
#
# 2. Dataframe

# %%
from pandas import Series, DataFrame

# %% [markdown]
# ## **Series**
# 1. Sequence of values, similar to numpy array
# 2. Each data value is associated to a label
#   - Left side represents the index (data labels)
#   - Right side represents the data

# %% [markdown]
# ### Create a Series

# %%
#sono sequenze di valori.
obj = pd.Series([4, 7, -5, 3]) #da una sequenza di valori ottengo una sequenze di coppie di valori, l'indice e i valori
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj.values
# Out:
# array([ 4,  7, -5,  3])

# %%
type(obj.values)
# Out:
# numpy.ndarray

# %%
obj.index  # like range(4) range(4) ritorna una seuquenza di valori che va da 0 a 4-1
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
type(obj.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %% [markdown]
# - We can specify the labels.

# %%
obj2 = pd.Series([4, 7, -5, 3], index=['d', 'b', 'a', 'c']) #è possibile specificare che indici voglio nelle series.
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2.index
# Out:
# Index(['d', 'b', 'a', 'c'], dtype='object')

# %%
type(obj2.index)

# %% [markdown]
# ### Numpy-like operations
# 1. Filtering with a boolean array
# 2. Scalar multiplication
# 3. Applying math functions
#
# They will preserve the index-value link

# %%
obj2['b'] #si può usare l'indice per accedere ai valori della series
# Out:
# np.int64(7)

# %%
obj2['b']=4 #si può anche modificare il valore nella series

# %%
obj2['b']
# Out:
# np.int64(4)

# %%
obj2

# %%
obj2[:'a']    # obj2[:3] funiona ugualmente   ATTENZIONE!!! si può usare lo slicing con i :, accedo alla porzione di series che va dall'inizio fino al valore con indice 'a'
# Out:
# d    4
# b    4
# a   -5
# dtype: int64

# %%
type(obj2[:2])

# %%
obj2

# %%
obj2[['c', 'a', 'd', 'd', 'a']]
# Out:
# c    3
# a   -5
# d    4
# d    4
# a   -5
# dtype: int64

# %%
type(obj2[['c', 'a', 'd', 'd', 'a']])
# Out:
# pandas.core.series.Series

# %%
obj2>2 #ritorna una series booleana in cui ho true se il valore è effettivamente > 2
# Out:
# d     True
# b     True
# a    False
# c     True
# dtype: bool

# %%
type(obj2>2) #si tratta sempre di una series

# %%
obj2[obj2 > 2] #ottengo solo la porzione di series che rispetta questa condizione
# Out:
# d    4
# b    4
# c    3
# dtype: int64

# %%
type(obj2[obj2 > 2])

# %%
obj2
# Out:
# d    4
# b    4
# a   -5
# c    3
# dtype: int64

# %%
'a' in obj2    # controllo se un valore è tra gli indici della Series
# Out:
# True

# %%
3 in obj2 #controllo che 3 sia tra gli inidici, in questo caso 3 è solo nei valori non negli indici  quindi ritorna false
# Out:
# False

# %%
3 in obj2.values #così controllo se 3 è nei valori
# Out:
# True

# %%
obj2.isin([3]) #ritorna una series booleana in cui c'è true nei valori in cui c'è 3
# Out:
# d    False
# b    False
# a    False
# c     True
# dtype: bool

# %%
obj2 == 3 #come isin([3])
# Out:
# d    False
# b    False
# a    False
# c     True
# dtype: bool

# %%
(obj2 == 3).any() #con sum sommo i valori = true di una certa serie booleana. esiste poi all e any. con all ritorna false siccoe non tutti valori sono = true, any ritorna invece true siccome c'è almeno un valore == 3

# %% [markdown]
# ### Math operations

# %% [markdown]
# Element wise casting
#
# Given $ X = \left[ x_1 \cdots x_n \right] $ then:<br> $ X * 2  = \left[ 2 x_1  \cdots 2{x_n} \right]
# $
#  <br> $
# e^X = \left[ e^{x_1} \cdots e^{x_n} \right]
# $

# %%
obj2

# %%
obj2 * 2

# %%
np.exp(obj2)

# %% [markdown]
# ### Use alignment of indexes for some operations

# %%
obj3 = pd.Series([1,2,3], index=['a', 'b', 'c']) #operazioni tra series diverse. la prima cosa che viene fatta in autometico è il match
#tra indici. le 2 series possono avere dimensioni diverse, se provo a fare la somma delle series vengon sommati i valori con lo stesso indice

# %%
obj4 = pd.Series([1,2,3], index=['a', 'd', 'e']) #obj3 e onjr4 hanno entrmabe 3 valori ma hanno valori di indici comuni e indici diversi, unico indice in comune è a
#verranno sommati quindi i valori con indice a

# %%
obj3 + obj4 #i valori con indiici diversi non vengono sommati, il valore associato a tutti gli altri inidici sara un not a number. se non vogliamo che il valore sia nullo si usa add
# Out:
# a    2.0
# b    NaN
# c    NaN
# d    NaN
# e    NaN
# dtype: float64

# %%
obj3.add(obj4, fill_value=0)
#con add si può usare il parametro fill value, se lo imposto = 0, non imposta a 0 i Nan ma fa in modo che la somma venga fatta con lo 0.
#per i valroi senza match  la somma viene fatta con lo 0

# %% [markdown]
# ### From Series to Dictionary and viceversa

# %% [markdown]
# - Another way to think about a Series is as a fixed-length, ordered dict, as it is a mapping of index values to data values.

# %%
obj2
#series è m0lto simile a dizionario siccome anche questo composta da key e value
#funzione to_dict serve per passare da una series ad un dizinoario. gli indici diventano le key e i valori i value
# Out:
# d    4
# b    4
# a   -5
# c    3
# dtype: int64

# %%
obj2.to_dict()
# Out:
# {'d': 4, 'b': 4, 'a': -5, 'c': 3}

# %%
obj2.to_dict().keys()
# Out:
# dict_keys(['d', 'b', 'a', 'c'])

# %%
obj2.to_dict().values()
# Out:
# dict_values([4, 4, -5, 3])

# %% [markdown]
# - The index of the resulting Series will have the dict's keys
# - The data values of the Series are the values of the dict

# %%
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000} #definisco un dizionario e specifico per ogni chiave il suo valore
obj3 = pd.Series(sdata) #partendo dal dizionario creato posso definire una series. pd.series vuole in input un dizionario e restituisce una series
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
obj3.index
# Out:
# Index(['Ohio', 'Texas', 'Oregon', 'Utah'], dtype='object')

# %%
obj3.values
# Out:
# array([35000, 71000, 16000,  5000])

# %%
type(obj3)

# %% [markdown]
# - Selecting the values of the Series based on the index values and forcing the order of the index

# %%
sdata
# Out:
# {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}

# %%
states = ['Ohio', 'California', 'Oregon', 'Texas']
obj4 = pd.Series(sdata, index=states)
obj4
# Out:
# Ohio          35000.0
# California        NaN
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
pd.isnull(obj4) #controllo dei valori nulli si può fare indiversi modi.
# Out:
# Ohio          False
# California     True
# Oregon        False
# Texas         False
# dtype: bool

# %%
pd.notnull(obj4) #opposto di isnull
# Out:
# Ohio           True
# California    False
# Oregon         True
# Texas          True
# dtype: bool

# %%
obj4.isnull() #altro modo per fare isnull
# Out:
# Ohio          False
# California     True
# Oregon        False
# Texas         False
# dtype: bool

# %% [markdown]
# ### Dropping entries: method *.drop*

# %%
obj = pd.Series(np.arange(5.), index=['a', 'b', 'c', 'd', 'e'])
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
obj.drop('c') #con drop do in input il valore dell'indice della riga ch voglio rimuovere. non va a modificare diretamente la serie.
# Out:
# a    0.0
# b    1.0
# d    3.0
# e    4.0
# dtype: float64

# %%
obj #come si può vedere tra i valori interni della series c'è ancora l'indice c. ciò accade perchè molte funzioni di pyton ha bisogno del parametro inplace= true per applicare la modifica direttamente sull'oggetto

# %%
new_obj = obj.drop('c') #una soluzione è fare il riassegnamento
new_obj
# Out:
# a    0.0
# b    1.0
# d    3.0
# e    4.0
# dtype: float64

# %%
obj.drop('c', inplace=True) #così modifico effettivamente l'oggetto
obj
# Out:
# a    0.0
# b    1.0
# d    3.0
# e    4.0
# dtype: float64

# %% [markdown]
# ### Giving a name to the Series
# - The name of the Series becomes its index or column name if it is used to form a DataFrame.
# - It is also used whenever displaying the Series using the interpreter.

# %%
obj4.name = 'population'
obj4 #posso dare nomi sia ai valri che agli idnici delle series
# Out:
# Ohio          35000.0
# California        NaN
# Oregon        16000.0
# Texas         71000.0
# Name: population, dtype: float64

# %%
obj4.index.name = 'state'

# %%
obj4
# Out:
# state
# Ohio          35000.0
# California        NaN
# Oregon        16000.0
# Texas         71000.0
# Name: population, dtype: float64

# %% [markdown]
# ## **DataFrame**
# 1. Represents a rectangular table of data
# 2. Contains an ordered collection of columns
# 3. Has indexes on columns and rows
# 4. Each column can have a different type (i.e., numeric, string, boolean, etc.)

# %% [markdown]
# ### Create a Dataframe

# %%
#i dataframe sono una collezione di series. sono delle tablelle in cui ci sono tante colonne e tante righe. ogni colonna di datafreame è una series
#così come ogni riga è una series. per inizializzara il fatafreame posso usare un dizionario. per inizializzare una series uso un dizionario in cui
#per ogni coppia il valore è uno unico, per un dataframe invece il valore è una sequenza di valore siccome voglio avere una tabella. il nome di ogni
#colonna sarà la chiave del dizionario. anche ogni riga del dataframe è una series qundi sia sulle colonne che sulle righe si possono usare le funzioni
#delle series
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
        'year': [2000, 2001, 2002, 2001, 2002, 2003],
        'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
frame = pd.DataFrame(data)

# %%
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
frame.shape #ritorna il numero di righe e di colonne
frame.shape[0] #accedo al numero di righe
frame.shape[1] #accedo al numero di colonne

# %%
frame.head(3) # default: 5. ritorna le prime n righe. di default n = 5
# Out:
#   state  year  pop
# 0  Ohio  2000  1.5
# 1  Ohio  2001  1.7
# 2  Ohio  2002  3.6

# %%
frame.tail(3) #ritorna le ultime n righe.
# Out:
#     state  year  pop
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
frame.sample() # default: 1. fornisce una riga a caso del dataframe
# Out:
#     state  year  pop
# 5  Nevada  2003  3.2

# %%
frame.columns #accedo all'indice delle colonne
# Out:
# Index(['state', 'year', 'pop'], dtype='object')

# %%
frame['state'] #ritorna la colonna state del dataframe. è una series
# Out:
# 0      Ohio
# 1      Ohio
# 2      Ohio
# 3    Nevada
# 4    Nevada
# 5    Nevada
# Name: state, dtype: object

# %%
frame.index.values #accedo all'indice delle righe. per le righe è stato utilizzato l'indice di default. anche alle righe posso specificarlo
# Out:
# array([0, 1, 2, 3, 4, 5])

# %% [markdown]
# If you specify a sequence of columns, the DataFrame’s columns will be arranged in that order

# %%
data
# Out:
# {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
#  'year': [2000, 2001, 2002, 2001, 2002, 2003],
#  'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}

# %%
pd.DataFrame(data, columns=['year', 'state', 'pop'])

# %% [markdown]
# Also, you can sepcify the row index.

# %%
frame2 = pd.DataFrame(data, columns=['year', 'state', 'pop', 'debt'],
                      index=['one', 'two', 'three', 'four', 'five', 'six']) #tramite index specifico anche l'indice delle righe
frame2
# Out:
#        year   state  pop debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2001  Nevada  2.4  NaN
# five   2002  Nevada  2.9  NaN
# six    2003  Nevada  3.2  NaN

# %%
frame2.columns #ritorna il nome delle colonne
# Out:
# Index(['year', 'state', 'pop', 'debt'], dtype='object')

# %%
frame2.index #ritorna i valori degli indici di righe
# Out:
# Index(['one', 'two', 'three', 'four', 'five', 'six'], dtype='object')

# %% [markdown]
# ### Indexing and Selection

# %% [markdown]
# - A column in a DataFrame can be retrieved as a Series either by dict-like notation or by attribute

# %%
frame2
# Out:
#        year   state  pop debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2001  Nevada  2.4  NaN
# five   2002  Nevada  2.9  NaN
# six    2003  Nevada  3.2  NaN

# %%
frame2['state'] #per accedere ad una certa colonna
# Out:
# one        Ohio
# two        Ohio
# three      Ohio
# four     Nevada
# five     Nevada
# six      Nevada
# Name: state, dtype: object

# %%
type(frame2['state'])
# Out:
# pandas.core.series.Series

# %%
frame2.state #altro modo per accedere ad una colonna
# Out:
# one        Ohio
# two        Ohio
# three      Ohio
# four     Nevada
# five     Nevada
# six      Nevada
# Name: state, dtype: object

# %%
frame2['year'][0] # or frame2.year[0]. se voglio accedere ad uno specifico valore di una colonna
# Out:
# /tmp/ipython-input-1823366968.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   frame2['year'][0] # or frame2.year[0]. se voglio accedere ad uno specifico valore di una colonna
# np.int64(2000)

# %% [markdown]
# - Rows can also be retrieved by position or name with the special **loc** attribute

# %%
frame2
# Out:
#        year   state  pop debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2001  Nevada  2.4  NaN
# five   2002  Nevada  2.9  NaN
# six    2003  Nevada  3.2  NaN

# %%
frame2.loc['three'] #serve per accedere all'indice specificato da me. tramite iloc avrei generato un errore, serve per accedere con l'indice inplicito quindi quello numerico
# Out:
# year     2002
# state    Ohio
# pop       3.6
# debt      NaN
# Name: three, dtype: object

# %%
frame2.iloc[2]
# Out:
# year     2002
# state    Ohio
# pop       3.6
# debt      NaN
# Name: three, dtype: object

# %%
type(frame2.loc['three'])
# Out:
# pandas.core.series.Series

# %%
frame2.loc['three'][0]
# Out:
# /tmp/ipython-input-2260567952.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   frame2.loc['three'][0]
# np.int64(2002)

# %% [markdown]
# Other options:
# - ***loc***: Access a group of rows and columns by label(s).
# - ***iloc***: Purely integer-location based rows and columns indexing for selection by position.
# - **[   :   ,   :   ]**: Access rows by integer or labels, or access columns by labels (columns can be omitted).

# %%
data = pd.DataFrame(np.arange(20).reshape((4, 5)),
                    index=['Ohio', 'Colorado', 'Utah', 'New York'],
                    columns=['zero', 'one', 'two', 'three', 'four'])
data
# Out:
#           zero  one  two  three  four
# Ohio         0    1    2      3     4
# Colorado     5    6    7      8     9
# Utah        10   11   12     13    14
# New York    15   16   17     18    19

# %%
data.loc['Ohio':'Colorado','two'] #posso definire un range di indice di riga e di colonna,
#prima specifico l'indice di riga e dopo la , l'indice di colonna. in questo caso per l'indice di colonna non è stato usato lo slicing
# Out:
# Ohio        2
# Colorado    7
# Name: two, dtype: int64

# %%
data[1:] # equals to
# data.loc['Colorado':]
# data.iloc[1:]

# %%
data[0:2] #--> [] by integer
# equals to (varie versioni equivalenti)
# data.loc['Ohio':'Colorado']
# data.iloc[0:2]
# data['Ohio':'Colorado'] # --> [] by label
# Out:
#           zero  one  two  three  four
# Ohio         0    1    2      3     4
# Colorado     5    6    7      8     9

# %%
data[['one']]

# %%
data[['one','two']]

# %%
# data.loc['Colorado':'Utah','two':]# equal to
data.iloc[1:3,2:]

# %%
data.loc[:,'one'] # equal to data['one']

# %%
data[['three', 'two', 'one']] # equals to
# data.loc[:,['three', 'two', 'one']]
# data.iloc[:,[2,1,0]]

# %%
data.loc[:, 'two':] # or
#data.iloc[:, 2:]
# data['two':] does not work

# %%
data.loc['Colorado']
# data['Colorado'] # does not work >>> None of [Index(['Colorado'], dtype='object')] are in the [columns] <<< --> in [] single labels are only for columns
# data.iloc[1]

# %%
data.loc[['Colorado']]
# data['Colorado':'Colorado']
# data.iloc[[1]]

# %%
# Row and columns selection
# Examples
data.loc['Ohio':'Colorado', 'three'] # data.loc[[row], [col]] -> label
data.loc['Colorado', ['two', 'three']] # data
data.loc['Ohio':'Colorado', 'three':'four']
data.iloc[[1, 2], 1:2]
data.loc[:'Utah', 'two']
data.iloc[0:2, :] # data.iloc[[row], [col]] -> posizionale
data.iloc[2:3, [3, 0, 1]] # Utah, cols: four, one, two

# %% [markdown]
# Why use loc? Differences between [] and .loc[]
#
# 1.   using **.loc**, the execution time is more than 3X times faster!
#
# 2.   loc is explicit: df.loc[row_indexer, column_index] can select rows and columns.
#
#  df[indexer] can only select rows or columns depending on the type of values in indexer and the type of column values the dataframe has.
#
# 3.  When a slice is passed to **df.loc** the **end-points are included** in the range. When a slice is passed to **df[...]**, the slice is interpreted as a **half-open** interval.

# %%
x = pd.DataFrame(np.arange(9).reshape(3,3))
x

# %%
x.loc[1:2].index.values

# %%
x[1:2].index.values

# %% [markdown]
# ### Filtering

# %%
data #anche nei dataframe posso filtrare i dati sul valore di questi dati
# Out:
#           zero  one  two  three  four
# Ohio         0    1    2      3     4
# Colorado     5    6    7      8     9
# Utah        10   11   12     13    14
# New York    15   16   17     18    19

# %%
data['three'] > 5 #solo valori > 5 nella colonna di indice three
# Out:
# Ohio        False
# Colorado     True
# Utah         True
# New York     True
# Name: three, dtype: bool

# %%
data[data['three'] > 5]
# data.loc[data['three'] > 5]
# data.iloc[data['three'] > 5] # NOT working >>> iLocation based boolean indexing cannot use an indexable as a mask

# %%
data >= 12 #non specificando alcuna colonna si verifica la condizione rispetto a tutti gli elementi del dataframe. ottengo quindi un dataframe booleano solo con valori true e false
# Out:
#            zero    one    two  three   four
# Ohio      False  False  False  False  False
# Colorado  False  False  False  False  False
# Utah      False  False   True   True   True
# New York   True   True   True   True   True

# %%
data[data >= 12] #ho nan nei valori < 12
# Does NOT work with loc & iloc
# Out:
#           zero   one   two  three  four
# Ohio       NaN   NaN   NaN    NaN   NaN
# Colorado   NaN   NaN   NaN    NaN   NaN
# Utah       NaN   NaN  12.0   13.0  14.0
# New York  15.0  16.0  17.0   18.0  19.0

# %%
data

# %%
data.iloc[:, :3] [(data.three > 5) & (data['four'] <15)] # combination. ogni condizione è tra (), più condizioni sono messe insieme con un espressione
#logica che sono o and & o or |.
# Out:
#           zero  one  two
# Colorado     5    6    7
# Utah        10   11   12

# %% [markdown]
# ### Modify a DataFrame

# %%
data
# Out:
#           zero  one  two  three  four
# Ohio         0    1    2      3     4
# Colorado     5    6    7      8     9
# Utah        10   11   12     13    14
# New York    15   16   17     18    19

# %%
data_copy_reference = data #è un assegnamento per riferimento

data_copy = data.copy() #copia del primo dataframe

data_view = data.iloc[2:,1:-1] #è un filtro del primo dataframe

# %%
data_copy_reference #sarà uguale al dataframe di partenza.
# Out:
#           zero  one  two  three  four
# Ohio         0    1    2      3     4
# Colorado     5    6    7      8     9
# Utah        10   11   12     13    14
# New York    15   16   17     18    19

# %%
data_copy_reference[data_copy_reference >= 12] = 100 #modifico sia data_copyreference che data siccome era un riferimeto a data
data_copy_reference
# Out:
#           zero  one  two  three  four
# Ohio         0    1    2      3     4
# Colorado     5    6    7      8     9
# Utah        10   11  100    100   100
# New York   100  100  100    100   100

# %%
data
# Out:
#           zero  one  two  three  four
# Ohio         0    1    2      3     4
# Colorado     5    6    7      8     9
# Utah        10   11  100    100   100
# New York   100  100  100    100   100

# %%
data_copy #non si modifica siccome data_copy era una copia dei dati fatta prima
# Out:
#           zero  one  two  three  four
# Ohio         0    1    2      3     4
# Colorado     5    6    7      8     9
# Utah        10   11   12     13    14
# New York    15   16   17     18    19

# %%
data_view #anche quando faccio il filtro sto facendo una copia per riferimento. quindi come data_copy reference anche data view è stata modificato
# Out:
#           one  two  three
# Utah       11  100    100
# New York  100  100    100

# %% [markdown]
# - Columns can be modified by assignment.

# %%
frame2

# %%
frame2['debt'] = 16.5 #voglio modificare tutti i dati della colonna debt con il valore 16.5
frame2
# 16.5 is **broadcasted** to [16.5, 16.5, ...] == [16.5] * frame2['debt'].shape[0]
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5  16.5
# two    2001    Ohio  1.7  16.5
# three  2002    Ohio  3.6  16.5
# four   2001  Nevada  2.4  16.5
# five   2002  Nevada  2.9  16.5
# six    2003  Nevada  3.2  16.5

# %% [markdown]
# - When you are assigning lists or arrays to a column, the value’s length must match the length of the DataFrame.

# %%
frame2['debt'] = [2,15.7,80,98,12,12]
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   2.0
# two    2001    Ohio  1.7  15.7
# three  2002    Ohio  3.6  80.0
# four   2001  Nevada  2.4  98.0
# five   2002  Nevada  2.9  12.0
# six    2003  Nevada  3.2  12.0

# %%
# viene mantenuta l'associazione con i valori dell'indice

val = pd.Series([-1.2, -1.5, -1.7], index=['two', 'four', 'five']) #viene fatto un match tra gli indici
frame2['debt'] = val
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   NaN
# two    2001    Ohio  1.7  -1.2
# three  2002    Ohio  3.6   NaN
# four   2001  Nevada  2.4  -1.5
# five   2002  Nevada  2.9  -1.7
# six    2003  Nevada  3.2   NaN

# %% [markdown]
# ### Dropping entries from an axis: method *.drop*

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
                    index=['Ohio', 'Colorado', 'Utah', 'New York'],
                    columns=['one', 'two', 'three', 'four'])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.drop(['Colorado', 'Ohio']) #quando applicao drop ai. dataframe devo selezionare se voglio droppare una riga o una colonna, s
#pcificando i valori dell'indice la drop viene applcata alle righe
# Out:
#           one  two  three  four
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.drop(['two', 'four'], axis=1) #se voglio eliminare le colonne devo indicare anche l'asse01
#come per le series per modificare effettivamente il dataframe devo indicare inplace
#data.drop(['two', 'four'], axis=1, inplace=true)
# Out:
#           one  three
# Ohio        0      2
# Colorado    4      6
# Utah        8     10
# New York   12     14

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %% [markdown]
# ### Arithmetic and Data Alignment

# %%
df1 = pd.DataFrame(np.arange(9.).reshape((3, 3)), columns=list('bcd'),
                   index=['Ohio', 'Texas', 'Colorado'])

df2 = pd.DataFrame(np.arange(12.).reshape((4, 3)), columns=list('bde'),
                   index=['Utah', 'Ohio', 'Texas', 'Oregon'])

# %%
df1
# Out:
#             b    c    d
# Ohio      0.0  1.0  2.0
# Texas     3.0  4.0  5.0
# Colorado  6.0  7.0  8.0

# %%
df2
# Out:
#           b     d     e
# Utah    0.0   1.0   2.0
# Ohio    3.0   4.0   5.0
# Texas   6.0   7.0   8.0
# Oregon  9.0  10.0  11.0

# %%
df1 + df2 #operazione ha effetto se i 2 dataframe hanno match tra gli indici. viene fatto match sia tra indice di riga che di colonna.
#se non voglio + si usa.add con il parametro fill_vale=0 (o un altro numero)
# Out:
#             b   c     d   e
# Colorado  NaN NaN   NaN NaN
# Ohio      3.0 NaN   6.0 NaN
# Oregon    NaN NaN   NaN NaN
# Texas     9.0 NaN  12.0 NaN
# Utah      NaN NaN   NaN NaN

# %% [markdown]
# #### Arithmetic methods with fill values

# %%
df1 = pd.DataFrame(np.arange(12.).reshape((3, 4)),
                   columns=list('abcd'))
df2 = pd.DataFrame(np.arange(20.).reshape((4, 5)),
                   columns=list('abcde'))

# %%
df1

# %%
df2

# %%
df2.loc[1, 'b'] = np.nan

# %%
df2

# %%
df1

# %%
df1-df2

# %%
df1.sub(df2, fill_value=12000)

# %%
1 / df1

# %%
df1 * 144

# %%
df1

# %% [markdown]
# ### Re-indexing

# %%
df1
# Out:
#             b    c    d
# Ohio      0.0  1.0  2.0
# Texas     3.0  4.0  5.0
# Colorado  6.0  7.0  8.0

# %%
df1.reindex(columns=['a', 'd', 'b', 'f'], fill_value=100) #se cambio indice di colonna posso cambiare lìordine ma anche aggiungere nuove colonne
#ho aggiunto colonna f che sarebbero tutti nan, aggiungo il fill_value = 100 allora tutti nan diventano 100
# Out:
#             a    d    b    f
# Ohio      100  2.0  0.0  100
# Texas     100  5.0  3.0  100
# Colorado  100  8.0  6.0  100

# %% [markdown]
# ## Operations between DataFrame and Series

# %%
frame = pd.DataFrame(np.arange(12.).reshape((4, 3)), #posso fare anche le operazioni tra series e dataframe
                     columns=list('bde'),
                     index=['Utah', 'Ohio', 'Texas', 'Oregon'])
frame

# %%
series2 = pd.Series(range(3), index=['b', 'e', 'f'])
series2

# %%
frame + series2

# %%
series3 = frame['d']
series3

# %%
frame

# %%
frame + series3

# %%
frame.add(series3, axis='index')

# %% [markdown]
# ### Function Application and Mapping
#
# - *apply*: Apply a function along an axis of the DataFrame
# - *map*: Apply a function to a Dataframe elementwise. This method applies a function that accepts and returns a scalar to every element of a DataFrame

# %%
frame = pd.DataFrame(np.random.randn(4, 3), columns=list('bde'),
                     index=['Utah', 'Ohio', 'Texas', 'Oregon'])
frame
# Out:
#                b         d         e
# Utah   -0.155703  1.095565  2.595661
# Ohio   -0.080945 -0.282643 -0.913103
# Texas  -1.285222 -0.157087 -1.208432
# Oregon -1.401280  1.590152  0.155002

# %%
frame['b'].max()

# %%
frame['b'].min()

# %%
frame

# %%
def diff_max_min(x): # x pd.Series
  return x.max() - x.min()

# %%
frame.apply(diff_max_min)

# %%
frame.apply(lambda x: x.max() - x.min())

# %%
frame.apply(diff_max_min, axis='columns')

# %%
def get_power_2(x): # x valore
  return np.power(x, 2)

frame.map(get_power_2)

# %% [markdown]
# ## Summarizing and Computing Descriptive Statistics

# %% [markdown]
# ### Describe

# %% [markdown]
# - describe
# - sum or cumsum
# - mean
# - count
# - value_counts

# %%
df = pd.DataFrame([[1.4, np.nan], [7.1, -4.5],
                   [np.nan, np.nan], [0.75, -1.3]],
                  index=['a', 'b', 'c', 'd'],
                  columns=['one', 'two'])
df
# Out:
#     one  two
# a  1.40  NaN
# b  7.10 -4.5
# c   NaN  NaN
# d  0.75 -1.3

# %%
df.describe() #per ogni colonna ci da i valori min max, i percentili ec... ci descrive il dataframe
# Out:
#             one       two
# count  3.000000  2.000000
# mean   3.083333 -2.900000
# std    3.493685  2.262742
# min    0.750000 -4.500000
# 25%    1.075000 -3.700000
# 50%    1.400000 -2.900000
# 75%    4.250000 -2.100000
# max    7.100000 -1.300000

# %%
df.info() #ci da anche i numero di valori non nulli, di che tipo sono i valori di ogni colonna
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, a to d
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   one     3 non-null      float64
#  1   two     2 non-null      float64
# dtypes: float64(2)
# memory usage: 268.0+ bytes

# %%
df

# %%
df.sum() #può essere fatta per ogni colonna e ogni riga spcificando raws o colomuns

# %%
df.sum(axis='columns')

# %%
df.mean(axis='columns', skipna=False)

# %%
df

# %%
df.max() #ritorna per ogni riga e colonna il max
# Out:
# one    7.1
# two   -1.3
# dtype: float64

# %%
df.idxmax() #ritorna l'indice di questo valore max
# Out:
# one    b
# two    d
# dtype: object

# %% [markdown]
# ### Unique Values, Value Counts, and Membership

# %%
obj = pd.Series(['c', 'a', 'c', 'a', 'a', 'b', 'b', 'c', 'c'])
obj
#se ho una series ( ho dataframe ) mi può ritornare utile sapere la sequenza dei valoei
# Out:
# 0    c
# 1    a
# 2    c
# 3    a
# 4    a
# 5    b
# 6    b
# 7    c
# 8    c
# dtype: object

# %%
uniques = obj.unique()
uniques #ritorna la sequenza dei valori unici
# Out:
# array(['c', 'a', 'b'], dtype=object)

# %%
obj.value_counts() #per ogni valore  unicoil numero di occorrenze
# Out:
# c    4
# a    3
# b    2
# Name: count, dtype: int64

# %%
obj

# %%
obj.map(lambda x: x in ['c', 'a']) #posso applicare delle funzioni usando map e dandogli in input una funzione che verrà applicata ad ogni valore della series
#dato x ritorna se x è uguale a c o ad a. ritorna una series booleana

# %%
mask = obj.isin(['c', 'a'])

# %%
mask

# %%
obj[mask]

# %%
data = pd.DataFrame({'Qu1': [1, 3, 4, 3, 4],
                     'Qu2': [2, 3, 1, 2, 3],
                     'Qu3': [1, 5, 2, 4, 4]})
data

# %%
pd.value_counts(data["Qu1"])
