# %% [markdown]
# <a href="https://colab.research.google.com/github/simonebugo/Big_Data/blob/main/Esercizio_in_aula2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Crea il DataFrame **vendite** che contiene la quantità di torte, biscotti e taralli (colonne) nei diversi giorni della settimana (righe).
#
#   Inserisci valori casuali compresi tra 5 e 50 (np.random.seed(100)).

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(100)
#indico la dimensione dell'array numpy (7,3)
vendite = pd.DataFrame(np.random.randint(5,50,size=(7,3)),
                     columns=['torte', 'biscotti', 'taralli'],
                     index=['lunedì', 'martedì', 'mercoledì', 'giovedì', 'venerdì', 'sabato','domenica'])
vendite
# Out:
#            torte  biscotti  taralli
# lunedì        13        29        8
# martedì       44        28       20
# mercoledì     15        35       39
# giovedì        7        39       19
# venerdì       39        29       20
# sabato        41        48       21
# domenica      14        34       27

# %% [markdown]
# 2. Visualizza le vendite di torte durante tutta la settimana.

# %%
vendite['torte']
# Out:
# lunedì       13
# martedì      44
# mercoledì    15
# giovedì       7
# venerdì      39
# sabato       41
# domenica     14
# Name: torte, dtype: int64

# %% [markdown]
# 3. Ottieni le vendite del giovedi.

# %%
vendite.loc['giovedì']
# Out:
# torte        7
# biscotti    39
# taralli     19
# Name: giovedì, dtype: int64

# %% [markdown]
# 4. Visualizza le vendite di biscotti e taralli dal mercoledì alla domenica.

# %%
vendite.loc['mercoledì':'domenica',['biscotti', 'taralli']]
#siccome sono vicini in questo caso si può fare vendite.loc['mercoledì':'domenica','biscotti':'taralli']
# Out:
#            biscotti  taralli
# mercoledì        35       39
# giovedì          39       19
# venerdì          29       20
# sabato           48       21
# domenica         34       27

# %% [markdown]
# 5. Qual è il totale delle vendite per ogni prodotto durante la settimana?

# %%
vendite.sum()
# Out:
# torte       173
# biscotti    242
# taralli     154
# dtype: int64

# %% [markdown]
# 6. Qual è il giorno con il massimo delle vendite di torte?

# %%
vendite['torte'].idxmax()
#vendite['torte'].argmax()
# Out:
# 'martedì'

# %% [markdown]
# 7. Aggiungi la colonna **Totale Vendite Giorno** che rappresenta la somma delle vendite di tutti i prodotti per ciascun giorno.

# %%
vendite['totale vendite giorno'] = vendite.sum(axis = 1)
vendite
# Out:
#            torte  biscotti  taralli  totale vendite giorno
# lunedì        13        29        8                     50
# martedì       44        28       20                     92
# mercoledì     15        35       39                     89
# giovedì        7        39       19                     65
# venerdì       39        29       20                     88
# sabato        41        48       21                    110
# domenica      14        34       27                     75

# %% [markdown]
# 8. Quali giorni hanno avuto un totale di vendite giornaliere superiori a 80?

# %%
(vendite['totale vendite giorno'] > 80).sum()
# Out:
# np.int64(4)
